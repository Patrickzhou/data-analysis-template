# %% [markdown]
# ##Team members responsible for this notebook:
#
#
#
# * team member 1 **Jiayuan Zhou **
#   Responsibilities:
# * team member 2 **Shorhon Gong    **  Responsibilities:
# * team member 3 **Haoyun Wu       **  Responsibilities:
# * team member 2 **Doe Gyi         **  Responsibilities:

# %% [markdown]
# ##Creating the directory structure

# %%
# %%bash
# pwd
# Out:
# /home/oski/project/data-analysis-template/notebooks

# %%
# %%bash
#
# mkdir ../script ../data ../data/raw ../data/cleaned ../data/simulated ../visualizations
# ls -r
# Out:
# README.md
# NB4_project_report.ipynb
# NB3_data_analysis.ipynb
# NB2_data_cleaning.ipynb
# NB1_data_gathering.ipynb

# %% [markdown]
# ##Downloading and displaying raw data

# %%
# %load_ext rmagic

# %% [markdown]
# We now download our mRNA raw data file:

# %%
# %%R
#
# url="https://db.tt/ZtbfsizV"
#
# raw_file ='../data/raw/rawbio.csv'
# download.file(url, raw_file, 'wget')

# %%
# %%R
#
# raw_data <- read.csv(raw_file,header = FALSE,sep = ",")

# %% [markdown]
# ##Loading raw data into data frames

# %%
# %%R
#
# data <- data.frame(raw_data[2:nrow(raw_data), 2:ncol(raw_data)])

# %%
# %%R
# #get names of rows & columns as characters
# x <- raw_data[,2:ncol(raw_data)]
# colnames <- unname(sapply(x[1,], as.character))
# y <- raw_data[2:nrow(raw_data),]
# rownames <- unname(sapply(y[,1], as.character))
#
# #set the dataframe
# colnames(data) <- colnames
# rownames(data) <- rownames
# temp=apply(data,2,as.numeric)

# %% [markdown]
# ##Using the data frame, we save our processed data into a csv file

# %%
# %%R
#
# write.csv(temp, '../data/raw/data_tobe_cleaned.csv')

# %%
# !head ../data/raw/data_tobe_cleaned.csv
# Out:
# "","Old","Old","Old","Young","Young","Young","Young","Old","Old","Old","Young","Old","Old","Old","Old","Young","Young","Young","Young","Old","Old","Old","Young","Young","Young","Young","Young","Young","Old","Young","Old","Young","Old","Young","Old","Young","Old","Young","Old","Young","Old","Young","Old","Young","Old","Young","Old","Young","Old","Old"
# ...
